# %%
import pandas as pd

train = pd.read_csv("data/train.csv")
train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8    ...      texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0    ...       0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0    ...       0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0    ...       0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0    ...       0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0    ...       0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
train_id = train['id']
train_lab = train['species']

# %%
train.drop(['id','species'],inplace=True,axis=1)
train.head()
# Out:
#     margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0  0.007812  0.023438  0.023438  0.003906  0.011719  0.009766  0.027344
# 1  0.005859  0.000000  0.031250  0.015625  0.025391  0.001953  0.019531
# 2  0.005859  0.009766  0.019531  0.007812  0.003906  0.005859  0.068359
# 3  0.000000  0.003906  0.023438  0.005859  0.021484  0.019531  0.023438
# 4  0.005859  0.003906  0.048828  0.009766  0.013672  0.015625  0.005859
#
#    margin8   margin9  margin10    ...      texture55  texture56  texture57  \
# 0      0.0  0.001953  0.033203    ...       0.007812   0.000000   0.002930
# 1      0.0  0.000000  0.007812    ...       0.000977   0.000000   0.000000
# 2      0.0  0.000000  0.044922    ...       0.154300   0.000000   0.005859
# 3      0.0  0.013672  0.017578    ...       0.000000   0.000977   0.000000
# 4      0.0  0.000000  0.005859    ...       0.096680   0.000000   0.021484
#
#    texture58  texture59  texture60  texture61  texture62  texture63  texture64
# 0   0.002930   0.035156        0.0        0.0   0.004883   0.000000   0.025391
# 1   0.000977   0.023438        0.0        0.0   0.000977   0.039062   0.022461
# 2   0.000977   0.007812        0.0        0.0   0.000000   0.020508   0.002930
# 3   0.000000   0.020508        0.0        0.0   0.017578   0.000000   0.047852
# 4   0.000000   0.000000        0.0        0.0   0.000000   0.000000   0.031250
#
# [5 rows x 192 columns]

# %%
train.describe()
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.017412    0.028539    0.031988    0.023280    0.014264    0.038579
# std      0.019739    0.038855    0.025847    0.028411    0.018390    0.052030
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.001953    0.001953    0.013672    0.005859    0.001953    0.000000
# 50%      0.009766    0.011719    0.025391    0.013672    0.007812    0.015625
# 75%      0.025391    0.041016    0.044922    0.029297    0.017578    0.056153
# max      0.087891    0.205080    0.156250    0.169920    0.111330    0.310550
#
#           margin7     margin8     margin9    margin10     ...       texture55  \
# count  990.000000  990.000000  990.000000  990.000000     ...      990.000000
# mean     0.019202    0.001083    0.007167    0.018639     ...        0.036501
# std      0.017511    0.002743    0.008933    0.016071     ...        0.063403
# min      0.000000    0.000000    0.000000    0.000000     ...        0.000000
# 25%      0.005859    0.000000    0.001953    0.005859     ...        0.000000
# 50%      0.015625    0.000000    0.005859    0.015625     ...        0.004883
# 75%      0.029297    0.000000    0.007812    0.027344     ...        0.043701
# max      0.091797    0.031250    0.076172    0.097656     ...        0.429690
#
#         texture56   texture57   texture58   texture59   texture60   texture61  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.005024    0.015944    0.011586    0.016108    0.014017    0.002688
# std      0.019321    0.023214    0.025040    0.015335    0.060151    0.011415
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000977    0.000000    0.004883    0.000000    0.000000
# 50%      0.000000    0.005859    0.000977    0.012695    0.000000    0.000000
# 75%      0.000000    0.022217    0.009766    0.021484    0.000000    0.000000
# max      0.202150    0.172850    0.200200    0.106450    0.578130    0.151370
#
#         texture62   texture63   texture64
# count  990.000000  990.000000  990.000000
# mean     0.020291    0.008989    0.019420
# std      0.039040    0.013791    0.022768
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000977
# 50%      0.003906    0.002930    0.011719
# 75%      0.023438    0.012695    0.029297
# max      0.375980    0.086914    0.141600
#
# [8 rows x 192 columns]

# %%
# %matplotlib inline

import matplotlib
matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt

train.boxplot(return_type='axes', figsize=(20, 4))

# %%
import seaborn as sns
import re
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(12,8)
vnames = list(train)
vnames = [re.compile('[^a-zA-Z]').sub('', x) for x in vnames]
vnames2 = list(vnames)
for i, item in enumerate(vnames):
    if i ==0: next
    if item == vnames[i-1]:
        vnames2[i]=''
axobj = sns.violinplot(data=train, inner="points", ax=ax, )    
sns.despine()
axobj.set_xticklabels(vnames2)
# Out:
# [<matplotlib.text.Text at 0x13039f5c0>,
#  <matplotlib.text.Text at 0x1303c2e80>,
#  <matplotlib.text.Text at 0x1306464a8>,
#  <matplotlib.text.Text at 0x130646710>,
#  <matplotlib.text.Text at 0x1303fb1d0>,
#  <matplotlib.text.Text at 0x130385e80>,
#  <matplotlib.text.Text at 0x1306eec88>,
#  <matplotlib.text.Text at 0x1306ee518>,
#  <matplotlib.text.Text at 0x1303f7438>,
#  <matplotlib.text.Text at 0x130381128>,
#  <matplotlib.text.Text at 0x1306f0860>,
#  <matplotlib.text.Text at 0x1306f0128>,
#  <matplotlib.text.Text at 0x1306424e0>,
#  <matplotlib.text.Text at 0x13037da58>,
#  <matplotlib.text.Text at 0x1306f5dd8>,
#  <matplotlib.text.Text at 0x1306f5240>,
#  <matplotlib.text.Text at 0x13063d128>,
#  <matplotlib.text.Text at 0x130379278>,
#  <matplotlib.text.Text at 0x1306f9710>,
#  <matplotlib.text.Text at 0x1306f92e8>,
#  <matplotlib.text.Text at 0x1303f4668>,
#  <matplotlib.text.Text at 0x130376eb8>,
#  <matplotlib.text.Text at 0x1303f0ba8>,
#  <matplotlib.text.Text at 0x1303f0d30>,
#  <matplotlib.text.Text at 0x1306fc940>,
#  <matplotlib.text.Text at 0x130373c50>,
#  <matplotlib.text.Text at 0x1306ff240>,
#  <matplotlib.text.Text at 0x1306ffe10>,
#  <matplotlib.text.Text at 0x13063b588>,
#  <matplotlib.text.Text at 0x1303ece10>,
#  <matplotlib.text.Text at 0x1306376a0>,
#  <matplotlib.text.Text at 0x130637e48>,
#  <matplotlib.text.Text at 0x13036f898>,
#  <matplotlib.text.Text at 0x131004198>,
#  <matplotlib.text.Text at 0x131008b38>,
#  <matplotlib.text.Text at 0x1303e89e8>,
#  <matplotlib.text.Text at 0x13100ccc0>,
#  <matplotlib.text.Text at 0x13100cbe0>,
#  <matplotlib.text.Text at 0x130634198>,
#  <matplotlib.text.Text at 0x1303e5c50>,
#  <matplotlib.text.Text at 0x131010908>,
#  <matplotlib.text.Text at 0x131010518>,
#  <matplotlib.text.Text at 0x13062f550>,
#  <matplotlib.text.Text at 0x131012908>,
#  <matplotlib.text.Text at 0x131016b70>,
#  <matplotlib.text.Text at 0x1303e0da0>,
#  <matplotlib.text.Text at 0x1303e0b38>,
#  <matplotlib.text.Text at 0x13062a278>,
#  <matplotlib.text.Text at 0x13101ce48>,
#  <matplotlib.text.Text at 0x1303dcb00>,
#  <matplotlib.text.Text at 0x1303dc860>,
#  <matplotlib.text.Text at 0x130628160>,
#  <matplotlib.text.Text at 0x1306dccf8>,
#  <matplotlib.text.Text at 0x130623320>,
#  <matplotlib.text.Text at 0x1306237f0>,
#  <matplotlib.text.Text at 0x1310232e8>,
#  <matplotlib.text.Text at 0x1303da668>,
#  <matplotlib.text.Text at 0x1306da198>,
#  <matplotlib.text.Text at 0x1306dad68>,
#  <matplotlib.text.Text at 0x13102a390>,
#  <matplotlib.text.Text at 0x1303d5e80>,
#  <matplotlib.text.Text at 0x1306206a0>,
#  <matplotlib.text.Text at 0x130620438>,
#  <matplotlib.text.Text at 0x1306d56d8>,
#  <matplotlib.text.Text at 0x13102dd68>,
#  <matplotlib.text.Text at 0x13061cb70>,
#  <matplotlib.text.Text at 0x13061ca58>,
#  <matplotlib.text.Text at 0x1310310b8>,
#  <matplotlib.text.Text at 0x1303d35c0>,
#  <matplotlib.text.Text at 0x1303cfe10>,
#  <matplotlib.text.Text at 0x1303cff60>,
#  <matplotlib.text.Text at 0x1306d3908>,
#  <matplotlib.text.Text at 0x131035780>,
#  <matplotlib.text.Text at 0x1310417b8>,
#  <matplotlib.text.Text at 0x1303cac88>,
#  <matplotlib.text.Text at 0x13103ac50>,
#  <matplotlib.text.Text at 0x131046828>,
#  <matplotlib.text.Text at 0x130610588>,
#  <matplotlib.text.Text at 0x1306d0a90>,
#  <matplotlib.text.Text at 0x1306d09b0>,
#  <matplotlib.text.Text at 0x1303c70b8>,
#  <matplotlib.text.Text at 0x1303c2ef0>,
#  <matplotlib.text.Text at 0x1306c9320>,
#  <matplotlib.text.Text at 0x1306c9898>,
#  <matplotlib.text.Text at 0x13103f668>,
#  <matplotlib.text.Text at 0x130602470>,
#  <matplotlib.text.Text at 0x13101ffd0>,
#  <matplotlib.text.Text at 0x13101f898>,
#  <matplotlib.text.Text at 0x130699898>,
#  <matplotlib.text.Text at 0x1303c0908>,
#  <matplotlib.text.Text at 0x13068a7f0>,
#  <matplotlib.text.Text at 0x13068ab70>,
#  <matplotlib.text.Text at 0x130695a58>,
#  <matplotlib.text.Text at 0x12fe5cb70>,
#  <matplotlib.text.Text at 0x12feab0b8>,
#  <matplotlib.text.Text at 0x12feabc18>,
#  <matplotlib.text.Text at 0x12fe86a90>,
#  <matplotlib.text.Text at 0x12febed30>,
#  <matplotlib.text.Text at 0x12fe7fa20>,
#  <matplotlib.text.Text at 0x12fe7ffd0>,
#  <matplotlib.text.Text at 0x1310259e8>,
#  <matplotlib.text.Text at 0x130606c88>,
#  <matplotlib.text.Text at 0x130606be0>,
#  <matplotlib.text.Text at 0x13060e3c8>,
#  <matplotlib.text.Text at 0x13132e9e8>,
#  <matplotlib.text.Text at 0x13060a208>,
#  <matplotlib.text.Text at 0x131049a58>,
#  <matplotlib.text.Text at 0x12fec5a90>,
#  <matplotlib.text.Text at 0x12fec5cc0>,
#  <matplotlib.text.Text at 0x12fecbeb8>,
#  <matplotlib.text.Text at 0x12fed20f0>,
#  <matplotlib.text.Text at 0x12f7e3dd8>,
#  <matplotlib.text.Text at 0x12f8f70f0>,
#  <matplotlib.text.Text at 0x12f8f7b00>,
#  <matplotlib.text.Text at 0x12f8fa160>,
#  <matplotlib.text.Text at 0x12f8fefd0>,
#  <matplotlib.text.Text at 0x12f8feb70>,
#  <matplotlib.text.Text at 0x12f8ed860>,
#  <matplotlib.text.Text at 0x12fa057b8>,
#  <matplotlib.text.Text at 0x12fa0a9b0>,
#  <matplotlib.text.Text at 0x12fa0acf8>,
#  <matplotlib.text.Text at 0x12fa0d898>,
#  <matplotlib.text.Text at 0x12fa10d68>,
#  <matplotlib.text.Text at 0x12fa101d0>,
#  <matplotlib.text.Text at 0x12fa141d0>,
#  <matplotlib.text.Text at 0x12fa181d0>,
#  <matplotlib.text.Text at 0x12fa18a20>,
#  <matplotlib.text.Text at 0x12fa1cb38>,
#  <matplotlib.text.Text at 0x12fa20f60>,
#  <matplotlib.text.Text at 0x12fa24b00>,
#  <matplotlib.text.Text at 0x12fa24c88>,
#  <matplotlib.text.Text at 0x12fa27b00>,
#  <matplotlib.text.Text at 0x12f832278>,
#  <matplotlib.text.Text at 0x12f832208>,
#  <matplotlib.text.Text at 0x12fa2b828>,
#  <matplotlib.text.Text at 0x12f82f2e8>,
#  <matplotlib.text.Text at 0x12f82f5f8>,
#  <matplotlib.text.Text at 0x12fa30da0>,
#  <matplotlib.text.Text at 0x12f8d48d0>,
#  <matplotlib.text.Text at 0x12f827780>,
#  <matplotlib.text.Text at 0x12f827c50>,
#  <matplotlib.text.Text at 0x12f8244a8>,
#  <matplotlib.text.Text at 0x12f8c88d0>,
#  <matplotlib.text.Text at 0x12f811080>,
#  <matplotlib.text.Text at 0x12f811d68>,
#  <matplotlib.text.Text at 0x12f8c15c0>,
#  <matplotlib.text.Text at 0x12f80ae10>,
#  <matplotlib.text.Text at 0x12f8069e8>,
#  <matplotlib.text.Text at 0x12f806ef0>,
#  <matplotlib.text.Text at 0x12f8be7b8>,
#  <matplotlib.text.Text at 0x12f802748>,
#  <matplotlib.text.Text at 0x12f7feef0>,
#  <matplotlib.text.Text at 0x12f7feda0>,
#  <matplotlib.text.Text at 0x12f7fc080>,
#  <matplotlib.text.Text at 0x12fa65710>,
#  <matplotlib.text.Text at 0x12f8b5d30>,
#  <matplotlib.text.Text at 0x12f8b5a90>,
#  <matplotlib.text.Text at 0x12f7f8eb8>,
#  <matplotlib.text.Text at 0x12f866438>,
#  <matplotlib.text.Text at 0x12f866b70>,
#  <matplotlib.text.Text at 0x12f7f4390>,
#  <matplotlib.text.Text at 0x12fa68908>,
#  <matplotlib.text.Text at 0x12f7f0f28>,
#  <matplotlib.text.Text at 0x12f7f0b70>,
#  <matplotlib.text.Text at 0x12f7eea90>,
#  <matplotlib.text.Text at 0x12f862f98>,
#  <matplotlib.text.Text at 0x12f7eacf8>,
#  <matplotlib.text.Text at 0x12f7eaac8>,
#  <matplotlib.text.Text at 0x12f85f438>,
#  <matplotlib.text.Text at 0x12f7e72b0>,
#  <matplotlib.text.Text at 0x12fa78e48>,
#  <matplotlib.text.Text at 0x12fa780b8>,
#  <matplotlib.text.Text at 0x12fa7ada0>,
#  <matplotlib.text.Text at 0x12fa83940>,
#  <matplotlib.text.Text at 0x12fa83710>,
#  <matplotlib.text.Text at 0x12fa876a0>,
#  <matplotlib.text.Text at 0x12f8586d8>,
#  <matplotlib.text.Text at 0x12f855c18>,
#  <matplotlib.text.Text at 0x12f855278>,
#  <matplotlib.text.Text at 0x12fa8e4a8>,
#  <matplotlib.text.Text at 0x12fa93eb8>,
#  <matplotlib.text.Text at 0x12fa973c8>,
#  <matplotlib.text.Text at 0x12fa97da0>,
#  <matplotlib.text.Text at 0x12f84a048>,
#  <matplotlib.text.Text at 0x12faa6358>,
#  <matplotlib.text.Text at 0x12f8457b8>,
#  <matplotlib.text.Text at 0x12f8450b8>,
#  <matplotlib.text.Text at 0x12faab5c0>,
#  <matplotlib.text.Text at 0x12faaee10>,
#  <matplotlib.text.Text at 0x12faba390>,
#  <matplotlib.text.Text at 0x12f83c550>,
#  <matplotlib.text.Text at 0x12f83ccf8>]

# %% [markdown]
# There is something about the shape features. Let's take a closer look.

# %%
train_shape = train.filter(regex='shape')
train_shape.describe()
# Out:
#            shape1      shape2      shape3      shape4      shape5      shape6  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.000739    0.000718    0.000694    0.000671    0.000650    0.000632
# std      0.000272    0.000268    0.000259    0.000254    0.000251    0.000251
# min      0.000168    0.000196    0.000148    0.000145    0.000139    0.000136
# 25%      0.000518    0.000506    0.000497    0.000483    0.000479    0.000464
# 50%      0.000716    0.000691    0.000675    0.000656    0.000639    0.000624
# 75%      0.000928    0.000904    0.000872    0.000836    0.000794    0.000758
# max      0.002390    0.002247    0.002112    0.001998    0.002151    0.002267
#
#            shape7      shape8      shape9     shape10     ...         shape55  \
# count  990.000000  990.000000  990.000000  990.000000     ...      990.000000
# mean     0.000617    0.000604    0.000590    0.000578     ...        0.000562
# std      0.000255    0.000265    0.000280    0.000297     ...        0.000278
# min      0.000093    0.000080    0.000088    0.000109     ...        0.000111
# 25%      0.000460    0.000441    0.000414    0.000396     ...        0.000384
# 50%      0.000604    0.000585    0.000562    0.000532     ...        0.000523
# 75%      0.000725    0.000706    0.000691    0.000686     ...        0.000663
# max      0.002305    0.002439    0.002521    0.002687     ...        0.001992
#
#           shape56     shape57     shape58     shape59     shape60     shape61  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.000569    0.000578    0.000591    0.000607    0.000626    0.000648
# std      0.000265    0.000254    0.000248    0.000245    0.000246    0.000248
# min      0.000096    0.000076    0.000060    0.000063    0.000042    0.000087
# 25%      0.000406    0.000415    0.000433    0.000445    0.000457    0.000462
# 50%      0.000544    0.000562    0.000588    0.000608    0.000632    0.000650
# 75%      0.000673    0.000690    0.000705    0.000736    0.000774    0.000810
# max      0.001941    0.001892    0.001861    0.001740    0.001760    0.001922
#
#           shape62     shape63     shape64
# count  990.000000  990.000000  990.000000
# mean     0.000675    0.000704    0.000732
# std      0.000252    0.000259    0.000268
# min      0.000134    0.000168    0.000166
# 25%      0.000477    0.000500    0.000513
# 50%      0.000674    0.000693    0.000711
# 75%      0.000849    0.000887    0.000924
# max      0.002090    0.002263    0.002431
#
# [8 rows x 64 columns]

# %%
# %matplotlib inline
sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(12,8)
vnames = list(train_shape)
vnames = [re.compile('[^a-zA-Z]').sub('', x) for x in vnames]
vnames2 = list(vnames)
for i, item in enumerate(vnames):
    if i ==0: next
    if item == vnames[i-1]:
        vnames2[i]=''
axobj = sns.violinplot(data=train_shape, inner="points", ax=ax, )    
sns.despine()
axobj.set_xticklabels(vnames2)
# Out:
# [<matplotlib.text.Text at 0x1303259b0>,
#  <matplotlib.text.Text at 0x12eb34fd0>,
#  <matplotlib.text.Text at 0x12e3e2390>,
#  <matplotlib.text.Text at 0x12e3e2e10>,
#  <matplotlib.text.Text at 0x12e3e6908>,
#  <matplotlib.text.Text at 0x12e3e9240>,
#  <matplotlib.text.Text at 0x12e3e9c88>,
#  <matplotlib.text.Text at 0x12e3ed780>,
#  <matplotlib.text.Text at 0x12e3f0278>,
#  <matplotlib.text.Text at 0x12e3f0d30>,
#  <matplotlib.text.Text at 0x12e3f3828>,
#  <matplotlib.text.Text at 0x12e3f7320>,
#  <matplotlib.text.Text at 0x12e3f7dd8>,
#  <matplotlib.text.Text at 0x12e3fb8d0>,
#  <matplotlib.text.Text at 0x12e3fe3c8>,
#  <matplotlib.text.Text at 0x12e3fee80>,
#  <matplotlib.text.Text at 0x12e402978>,
#  <matplotlib.text.Text at 0x12e405470>,
#  <matplotlib.text.Text at 0x12e405f28>,
#  <matplotlib.text.Text at 0x12e40aa20>,
#  <matplotlib.text.Text at 0x12e902518>,
#  <matplotlib.text.Text at 0x12e902fd0>,
#  <matplotlib.text.Text at 0x12e905ac8>,
#  <matplotlib.text.Text at 0x12e90a5c0>,
#  <matplotlib.text.Text at 0x12e90d0b8>,
#  <matplotlib.text.Text at 0x12e90db70>,
#  <matplotlib.text.Text at 0x12e90f668>,
#  <matplotlib.text.Text at 0x12e914160>,
#  <matplotlib.text.Text at 0x12e914c18>,
#  <matplotlib.text.Text at 0x12e917710>,
#  <matplotlib.text.Text at 0x12e91c208>,
#  <matplotlib.text.Text at 0x12e91ccc0>,
#  <matplotlib.text.Text at 0x12e91f7b8>,
#  <matplotlib.text.Text at 0x12e9222b0>,
#  <matplotlib.text.Text at 0x12e922d68>,
#  <matplotlib.text.Text at 0x12e926860>,
#  <matplotlib.text.Text at 0x12e92a358>,
#  <matplotlib.text.Text at 0x12e92ae10>,
#  <matplotlib.text.Text at 0x12e92f908>,
#  <matplotlib.text.Text at 0x12e931400>,
#  <matplotlib.text.Text at 0x12e931eb8>,
#  <matplotlib.text.Text at 0x12e9359b0>,
#  <matplotlib.text.Text at 0x12e9384a8>,
#  <matplotlib.text.Text at 0x12e938f60>,
#  <matplotlib.text.Text at 0x12e93fa58>,
#  <matplotlib.text.Text at 0x12e942550>,
#  <matplotlib.text.Text at 0x12e945048>,
#  <matplotlib.text.Text at 0x12e945b00>,
#  <matplotlib.text.Text at 0x12e9495f8>,
#  <matplotlib.text.Text at 0x12e94c0f0>,
#  <matplotlib.text.Text at 0x12e94cba8>,
#  <matplotlib.text.Text at 0x12e9506a0>,
#  <matplotlib.text.Text at 0x12e954198>,
#  <matplotlib.text.Text at 0x12e954c50>,
#  <matplotlib.text.Text at 0x12e958748>,
#  <matplotlib.text.Text at 0x12e95b240>,
#  <matplotlib.text.Text at 0x12e95bcf8>,
#  <matplotlib.text.Text at 0x12e95e7f0>,
#  <matplotlib.text.Text at 0x12e9622e8>,
#  <matplotlib.text.Text at 0x12e962da0>,
#  <matplotlib.text.Text at 0x12e966898>,
#  <matplotlib.text.Text at 0x12e96b390>,
#  <matplotlib.text.Text at 0x12e96be48>,
#  <matplotlib.text.Text at 0x12e96e940>]

# %% [markdown]
# Well this is a lovely sinusoidal pattern. What does it mean?
